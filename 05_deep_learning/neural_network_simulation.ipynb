# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# Simulate data
np.random.seed(42)
X = np.linspace(0, 10, 1000)
Y = 4 + 3 * X - 0.7 * X**2 + 0.05 * X**3 + np.random.normal(scale=1.5, size=X.shape)  # Quadratic relationship with noise

# Define the MLPRegressor with a single hidden layer of 3 neurons and ReLU activation function
mlp = MLPRegressor(hidden_layer_sizes=(8,6), activation='relu', alpha=0, max_iter=1000000, solver='adam', learning_rate='adaptive')

# Fit the model to the data
mlp.fit(X.reshape(-1, 1), Y)

# Predict Y using the fitted model
Y_pred = mlp.predict(X.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue', label='Data')
plt.plot(X, Y_pred, color='red', label='Neural Net', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatterplot with Neural Net Predictions')
plt.legend()
plt.show()

# View the weights (coefs) of the model
print("Weights between input and hidden layer:", mlp.coefs_[0])
print("Weights between first hidden and second hidden layer:", mlp.coefs_[1])
print("Weights between hidden and output layer:", mlp.coefs_[2])

# View the biases (intercepts) of the model
print("Biases of the hidden layer:", mlp.intercepts_[0])
print("Biases of the second hidden layer:", mlp.intercepts_[1])
print("Biases of the output layer:", mlp.intercepts_[2])
# Out:
# Weights between input and hidden layer: [[-0.15603008 -0.23114562  0.65009663  0.71779981 -0.76491662  1.00185798
#   -0.73162783  0.18265982]]
# Weights between first hidden and second hidden layer: [[ 6.95726440e-01  1.04988508e+00 -1.17950757e-01 -1.80895447e+00
#    6.66585461e-01  3.03221861e-01]
#  [-2.72639528e-02 -5.76490010e-02 -4.03803871e-01 -2.58583088e+00
#    1.00595049e+00 -3.67635188e-01]
#  [ 8.02953153e-01 -3.58947237e-02 -4.78114679e-01  6.04404653e-01
#    3.83387699e-01 -2.36236169e-03]
#  [ 2.38866054e-01  4.51109609e-01 -4.16166694e-01  8.60043121e-01
#    7.83867804e-01  1.96822525e-01]
#  [-3.93391275e-01  2.35974161e-01 -5.60123764e-01 -6.14520125e-01
#   -3.17267573e-01 -4.89380371e-02]
#  [ 6.83965483e-01  4.96603635e-01  2.59674794e-01  3.97224622e-02
#   -5.62584525e-03 -1.68849894e-01]
#  [ 6.38483154e-01 -6.02138412e-01  4.80557032e-01  1.03010290e-01
#   -8.03712823e-02  2.94931508e-01]
#  [-6.19002028e-02  4.44498672e-01  4.58050600e-01  2.59626723e-01
#   -3.34788519e-01  1.20914963e-01]]
# Weights between hidden and output layer: [[ 0.55011129]
#  [ 1.01579474]
#  [-0.55590659]
#  [-1.00708945]
#  [ 1.05549378]
#  [-0.5907159 ]]
# Biases of the hidden layer: [ 1.03708188  1.48254613  0.34744263  0.38887452 -0.26217674 -0.01499452
#  -0.68566958  0.56417667]
# Biases of the second hidden layer: [ 0.18854156 -0.7289742   0.08910074  0.87856333 -0.03070731 -0.48239113]
# Biases of the output layer: [0.35335765]
